# %%
import numpy as np
import pandas as pd
from sample_reader.sample_reader import SampleReader

# %%
samples_fv = SampleReader().read('AbVitro/flu_time_course/FV/', ['25'])
samples_gmc = SampleReader().read('AbVitro/flu_time_course/GMC/', ['8'])
samples_ido = SampleReader().read('AbVitro/flu_time_course/IDO/')
samples_age = SampleReader().read('age/')
samples_paired = SampleReader().read('AbVitro/paired/')

# %%
from shm_kmer_model_estimator.shm_kmer_model_estimator import ShmKmerModelEstimator

# %%
estimator = ShmKmerModelEstimator()
est_model = estimator.estimate_models_of_one_type((samples_age,
                                                   samples_ido,
                                                   samples_fv,
                                                   samples_gmc,
                                                   samples_paired
                                                  ),
                                                  chains=['IGH'])
# Out:
# NoKNeighbours: IGH
# /Users/andrewbzikadze/anaconda/envs/python2.7/lib/python2.7/site-packages/numpy/core/_methods.py:59: RuntimeWarning: Mean of empty slice.
#   warnings.warn("Mean of empty slice.", RuntimeWarning)
# Trivial: IGH

# %%
est_model['NoKNeighbours']['IGH'].get_raw_dataset()
# Out:
#        beta_shape1  beta_shape2  dir_shape1  dir_shape2  dir_shape3  \
# AAAAA     7.146083    97.292401    7.398240   22.785610    3.108762
# AAAAC     5.632682    87.909398    4.517756   12.853307    2.116935
# AAAAG    12.202138   276.022835    5.444207   14.847967    1.756008
# AAAAT     2.184276    19.908167    2.096816   15.979570    1.122468
# AAACA     5.759037   106.243574    4.398708    9.349134    1.289345
# AAACC     7.042889   111.368976    6.213103   15.622429    4.015588
# AAACG     0.139305     2.665921         NaN         NaN         NaN
# AAACT     3.828654    56.912397    5.437280    6.512642    4.080202
# AAAGA     1.513937    84.662514    1.178537    4.008989    0.575260
# AAAGC     6.512415   135.272392    4.276626   11.904449    2.483389
# AAAGG     8.304648   159.088129    7.398597   26.467969    4.681457
# AAAGT     1.023450     6.105245    0.477778   10.204603    0.319437
# AAATA     3.078904    35.594641    2.526062   10.653097    1.867977
# AAATC     3.059427    54.363526    3.494194   25.916575    1.750833
# AAATG     3.765362    90.092067   11.190378   12.175104   12.149709
# AAATT     1.690517    15.146079         NaN         NaN         NaN
# AACAA     3.074385    32.022198    2.198306    4.095479    5.401044
# AACAC    10.224006   150.778375   11.632318    9.498367   33.150787
# AACAG     5.500997    83.147830   10.726163    8.179419   35.248877
# AACAT     7.670251    88.430449    4.067543    2.689207   18.290146
# AACCA     4.882153    39.762817    3.928384    9.035657   27.341191
# AACCC     6.285317    74.576134    5.376098    7.194125   41.536975
# AACCG     7.361335    42.045171    1.982246    6.510637    9.338359
# AACCT     0.287663     0.712337         NaN         NaN         NaN
# AACGA     2.386148    23.396811         NaN         NaN         NaN
# AACGC     3.936707    84.302780    2.928824    3.462326   11.983897
# AACGG          NaN          NaN         NaN         NaN         NaN
# AACGT     1.094974     1.772979    4.498957    7.268967    1.773798
# AACTA     2.622088    16.065865   11.233778   26.172862   27.707954
# AACTC     5.675755    39.468572    6.947272   25.068888   54.872339
# ...            ...          ...         ...         ...         ...
# TTGCA                 0.981568                0.525293
# TTGCC                 0.989524                     NaN
# TTGCG                      NaN                     NaN
# TTGCT                 0.202136                     NaN
# TTGGA                 0.986431                0.252029
# TTGGC                 0.990014                0.326289
# TTGGG                 0.992043                0.262752
# TTGGT                 0.966904                0.497305
# TTGTA                 0.780573                0.420357
# TTGTC                 0.983329                     NaN
# TTGTG                 0.979547                0.249506
# TTGTT                 0.851380                     NaN
# TTTAA                 1.000000                     NaN
# TTTAC                 0.928271                0.109292
# TTTAG                 0.917336                0.088355
# TTTAT                 0.957751                0.392217
# TTTCA                 0.951392                0.147869
# TTTCC                 0.980036                0.127825
# TTTCG                 0.969659                     NaN
# TTTCT                 0.982519                     NaN
# TTTGA                 0.969302                0.093113
# TTTGC                 0.887267                     NaN
# TTTGG                 0.965566                0.214656
# TTTGT                 0.980395                     NaN
# TTTTA                 0.977633                     NaN
# TTTTC                 0.976137                     NaN
# TTTTG                 0.969780                     NaN
# TTTTT                 0.962932                0.223785
#
#        start_point_dir_shape2  start_point_dir_shape3
# AAAAA                0.684766                0.092108
# AAAAC                0.660704                0.102724
# AAAAG                0.677450                0.076126
# AAAAT                0.830609                0.047619
# AAACA                0.625159                0.078697
# AAACC                0.606894                0.152330
# AAACG                     NaN                     NaN
# AAACT                0.406988                0.262961
# AAAGA                0.702830                0.104249
# AAAGC                0.642090                0.131030
# AAAGG                0.685887                0.121871
# AAAGT                0.922850                0.019176
# AAATA                0.715844                0.115245
# AAATC                0.833977                0.054267
# AAATG                0.342775                0.341794
# AAATT                     NaN                     NaN
# AACAA                0.355936                0.461817
# AACAC                0.171632                0.610903
# AACAG                0.151811                0.650426
# AACAT                0.108734                0.730442
# AACCA                0.225536                0.681576
# AACCC                0.130514                0.768938
# AACCG                0.359094                0.522971
# AACCT                     NaN                     NaN
# AACGA                     NaN                     NaN
# AACGC                0.189150                0.654493
# AACGG                     NaN                     NaN
# AACGT                0.541562                0.122605
# AACTA                0.402041                0.426658
# AACTC                0.290207                0.631777
# ...                       ...                     ...
# TTGAG                0.642237                0.206474
# TTGAT                0.371686                0.151584
# TTGCA                0.072605                0.402102
# TTGCC                     NaN                     NaN
# TTGCG                     NaN                     NaN
# TTGCT                     NaN                     NaN
# TTGGA                0.334327                0.413645
# TTGGC                0.128619                0.545092
# TTGGG                0.211637                0.525610
# TTGGT                0.323697                0.178998
# TTGTA                0.477676                0.101966
# TTGTC                     NaN                     NaN
# TTGTG                0.431400                0.319094
# TTGTT                     NaN                     NaN
# TTTAA                     NaN                     NaN
# TTTAC                0.789931                0.100776
# TTTAG                0.776986                0.134659
# TTTAT                0.296962                0.310822
# TTTCA                0.196657                0.655474
# TTTCC                0.338583                0.533593
# TTTCG                     NaN                     NaN
# TTTCT                     NaN                     NaN
# TTTGA                0.520625                0.386262
# TTTGC                     NaN                     NaN
# TTTGG                0.369872                0.415472
# TTTGT                     NaN                     NaN
# TTTTA                     NaN                     NaN
# TTTTC                     NaN                     NaN
# TTTTG                     NaN                     NaN
# TTTTT                0.533656                0.242559
#
# [1024 rows x 12 columns]

# %%
import shm_kmer_model.shm_kmer_model as shm_kmer_model

# %%
#est_model['NoKNeighbours']['IGH'].to_csv('/Users/andrewbzikadze/chihua/datasets/shm_model_no_kneighbours.csv', na_rep='NaN')
#est_model['Trivial']['IGH'].to_csv('/Users/andrewbzikadze/chihua/datasets/shm_model_trivial.csv', na_rep='NaN')

# %%
def apply_to_datasets(datasets, func):
    result = dict.fromkeys(datasets)
    for strategy in datasets:
        result[strategy] = dict.fromkeys(datasets[strategy])
        for chain_type in datasets[strategy]:
            result[strategy][chain_type] = \
            func(datasets[strategy][chain_type].get_raw_dataset())
    return result

# %%
import shm_kmer_model_estimator.standard_model_estimations as standard_model_estimations
est_model = standard_model_estimations.full_igh_model_extended_base()

# %%
apply_to_datasets(est_model, (lambda x: x.isnull().any(axis=1).mean()))
# Out:
# {'NoKNeighbours': {'IGH': 0.3388671875}, 'Trivial': {'IGH': 0.255859375}}

# %%
apply_to_datasets(est_model, (lambda x: x['success_optim_beta'].mean()))
# Out:
# {'NoKNeighbours': {'IGH': 0.80078125, 'IGK': 0.736328125, 'IGL': 0.7138671875},
#  'Trivial': {'IGH': 0.8447265625, 'IGK': 0.837890625, 'IGL': 0.8623046875}}

# %%
apply_to_datasets(est_model, lambda x: x['success_optim_dir'].mean())
# Out:
# {'NoKNeighbours': {'IGH': 0.9306640625, 'IGK': 0.9287109375, 'IGL': 0.9375},
#  'Trivial': {'IGH': 0.970703125, 'IGK': 0.90625, 'IGL': 0.900390625}}

# %%
def sd_beta(x):
    a, b = x['beta_shape1'], x['beta_shape2']
    return np.sqrt(a * b / ((a + b)**2 * (a + b + 1)))

# %%
apply_to_datasets(est_model, sd_beta)
None

# %%
def sd_dir(x):
    alpha = x.ix[:, np.arange(2, 5)]
    alpha_sum = np.sum(alpha)
    denominator = alpha_sum * np.sqrt(alpha_sum + 1)
    return np.sqrt(alpha * (alpha_sum - alpha)) / denominator

# %%
apply_to_datasets(est_model, sd_dir)
None

# %%
apply_to_datasets(est_model, (lambda x: np.nanstd(np.array(x.ix[:,0:2].T / np.sum(x.ix[:,0:2], axis=1)).T - \
                                        np.array(x.ix[:,7:9]))))
# Out:
# {'NoKNeighbours': {'IGH': 0.017479290381984831},
#  'Trivial': {'IGH': 0.014590950009082691}}

# %%
apply_to_datasets(est_model, (lambda x: np.nanstd(np.array(x.ix[:,2:5].T / np.sum(x.ix[:,2:5], axis=1)).T - \
                                        np.array(x.ix[:,9:12]))))
# Out:
# {'NoKNeighbours': {'IGH': 0.033168516056584725},
#  'Trivial': {'IGH': 0.02091559250794919}}
